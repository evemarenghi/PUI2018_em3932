# %% [markdown]
# # SQL CARTO QUERY FUNCTION
# # written for PUI2016_Python2

# %% [markdown]
# ##### This notebook is set up to link as a default to the fb55 account.  To turn in the homework use the citibike dataset - check that you are able to read in about 40k rows

# %%
try:
    from StringIO import BytesIO as io
except ImportError:
    from io import BytesIO as io

try:
    from urllib import urlencode as urlencode
except ImportError:
    from urllib.parse import urlencode as urlencode
    
try:
    from urllib import urlopen as urlopen
except ImportError:
    from urllib.request import urlopen as urlopen
    
try:
    from urllib2 import HTTPError as HTTPError
except ImportError:
    from urllib.error import HTTPError as HTTPError

import ast
import pandas as pd

try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib

# %%
# append a query to this API address 
# all database processing runs on Carto DB's server 
API_URL = 'https://fb55.carto.com:443/api/v2/sql?q='

def queryCartoDB(query, formatting = 'CSV', source = API_URL):
    '''queries carto datasets from a given carto account
    Arguments: 
    query - string: a valid sql query string
    format - outlut format  OPTIONAL (default CSV)
    source - a valid sql api endpoint OPTIONAL (default carto fb55 account)
    Returns:
    the return of the sql query AS A STRING
    NOTES:
    designed for the carto API, tested only with CSV return format'''
    
    
    data = urlencode({'format': formatting, 'q': query}).encode("utf-8")
    try:fb55.citibike
        response = urlopen(source, data)
        return response.read()
    except HTTPError as e:
        raise (ValueError('\n'.join(ast.literal_eval(e.readline())['error'])))
        
def get_data(query):
    try:
        return pd.read_csv(io(queryCartoDB(query)), sep = ',')
    except ValueError as v:
        print (str(v))

# %% [markdown]
# # Task 1 — Familiarize with SQL Clauses

# %%
# Sort data by start_station_id, tripduration
query = '''
SELECT * 
FROM acs16
'''

table = get_data(query)
table.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-593a9bd0d469> in <module>()
#       5 '''
#       6
# ----> 7 table = get_data(query)
#       8 table.head(5)
#
# NameError: name 'get_data' is not defined

# %%
# Sort data by start_station_id, tripduration
# Only checking trips with duration <= 3 hours 
query = '''
SELECT start_station_id, tripduration
FROM fb55.citibike
WHERE tripduration <= (60*60*3)
ORDER BY 1,2 ASC
'''

table = get_data(query)
table.head(5)
# Out:
#    start_station_id  tripduration
# 0                72           107
# 1                72           189
# 2                72           229
# 3                72           248
# 4                72           252

# %%
# Only show the top 10 records (aka head and tail in SQL) 
query = '''
SELECT *
FROM fb55.citibike
ORDER BY cartodb_id ASC
LIMIT 10
'''

table = get_data(query)
table.head(10)
# Out:
#    the_geom                 start_station_name  the_geom_webmercator  field_1  \
# 0       NaN                    8 Ave & W 31 St                   NaN       70
# 1       NaN                 E 17 St & Broadway                   NaN       71
# 2       NaN  Grand Army Plaza & Central Park S                   NaN       72
# 3       NaN                  6 Ave & Broome St                   NaN       73
# 4       NaN        Lawrence St & Willoughby St                   NaN       74
# 5       NaN       Willoughby Ave & Walworth St                   NaN       75
# 6       NaN                    W 56 St & 6 Ave                   NaN       76
# 7       NaN                     E 4 St & 2 Ave                   NaN       77
# 8       NaN           Washington Pl & Broadway                   NaN       78
# 9       NaN              Greenwich Ave & 8 Ave                   NaN       79
#
#    start_station_longitude  tripduration               starttime  \
# ...

# %%
# Only show the last 10 records (aka head and tail in SQL) 
query = '''
SELECT *
FROM fb55.citibike
ORDER BY cartodb_id DESC
LIMIT 10 
'''

table = get_data(query)
table.head(10)
# Out:
#    the_geom     start_station_name  the_geom_webmercator  field_1  \
# 0       NaN         E 4 St & 2 Ave                   NaN    46199
# 1       NaN     Carmine St & 6 Ave                   NaN    46198
# 2       NaN        5 Ave & E 29 St                   NaN    46197
# 3       NaN        5 Ave & E 29 St                   NaN    46196
# 4       NaN        W 20 St & 8 Ave                   NaN    46195
# 5       NaN        1 Ave & E 44 St                   NaN    46194
# 6       NaN        E 20 St & 2 Ave                   NaN    46193
# 7       NaN  Warren St & Church St                   NaN    46192
# 8       NaN       W 47 St & 10 Ave                   NaN    46191
# 9       NaN        W 17 St & 8 Ave                   NaN    46190
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.989780           917  2015-02-07 23:59:00+00
# 1               -74.002150           548  2015-02-07 23:58:00+00
# ...

# %%
# List all unique start_station_id values 
query = '''
SELECT DISTINCT start_station_id
FROM fb55.citibike
ORDER BY start_station_id ASC
'''

table = get_data(query)
table.head(5)
# Out:
#    start_station_id  Unnamed: 1
# 0                72         NaN
# 1                79         NaN
# 2                82         NaN
# 3                83         NaN
# 4               116         NaN

# %%
# Count the number of trips (aka wc -l in SQL)
query = '''
SELECT COUNT(*) AS num_trips
FROM fb55.citibike
'''

table = get_data(query)
table.head(5)
# Out:
#    num_trips  Unnamed: 1
# 0      46200         NaN

# %%
# Find the average, max, and min trip duration
query = '''
SELECT AVG(tripduration) AS avg_duration, MAX(tripduration) AS max_duration, MIN(tripduration) AS min_duration
FROM fb55.citibike
'''

table = get_data(query)
table.head(5)
# Out:
#    avg_duration  max_duration  min_duration
# 0    675.865823         43016            60

# %% [markdown]
# # Task 2 — Working with date/time

# %%
# Selecting trips started on Feb-02-2015 only
query = '''
SELECT * 
FROM fb55.citibike
WHERE EXTRACT(DAY FROM starttime) = 2
'''

table = get_data(query)
table.head(5)
# Out:
#    the_geom    start_station_name  the_geom_webmercator  field_1  \
# 0       NaN       5 Ave & E 29 St                   NaN     7433
# 1       NaN  Allen St & Hester St                   NaN     7779
# 2       NaN     E 5 St & Avenue C                   NaN       11
# 3       NaN       9 Ave & W 16 St                   NaN      627
# 4       NaN       9 Ave & W 16 St                   NaN      991
#
#    start_station_longitude  tripduration               starttime  \
# 0               -73.986831           376  2015-02-02 17:44:00+00
# 1               -73.991908          1217  2015-02-02 20:12:00+00
# 2               -73.979955          1312  2015-02-02 11:07:00+00
# 3               -74.004432           444  2015-02-02 00:40:00+00
# 4               -74.004432           438  2015-02-02 00:40:00+00
#
#                  stoptime  start_station_id  cartodb_id  \
# 0  2015-02-02 17:50:00+00               474        7367
# 1  2015-02-02 20:32:00+00               361        7712
# ...

# %%
# Selecting trips started on the weekends - What are average trip duration during weekends?
query = '''
SELECT day, AVG(tripduration) AS avg_duration
FROM
(SELECT EXTRACT(DAY FROM starttime) as day, tripduration 
FROM fb55.citibike) AS subquery
WHERE day = 1 OR day = 2
GROUP BY day
ORDER BY day
'''

table = get_data(query)
table.head(10)
# Out:
#    day  avg_duration
# 0    1    638.149200
# 1    2    920.862234

# %%
# What are average trip duration during weekdays?
query = '''
SELECT day, AVG(tripduration) AS avg_duration
FROM
(SELECT EXTRACT(DAY FROM starttime) as day, tripduration 
FROM fb55.citibike) AS subquery
WHERE day != 1 AND day != 2
GROUP BY day
ORDER BY day
'''

table = get_data(query)
table.head(10)
# Out:
#    day  avg_duration
# 0    3    767.224443
# 1    4    697.556559
# 2    5    623.396720
# 3    6    637.116968
# 4    7    686.460825

# %% [markdown]
# # Task 3 — Working with Space

# %%
# Showing the list of start station locations 
query = '''
SELECT start_station_name
FROM fb55.citibike
GROUP BY start_station_name
'''

table = get_data(query)
table.head(20)
# Out:
#                start_station_name  Unnamed: 1
# 0            E 30 St & Park Ave S         NaN
# 1         Pearl St & Anchorage Pl         NaN
# 2                 W 56 St & 6 Ave         NaN
# 3                  West Thames St         NaN
# 4         Bank St & Washington St         NaN
# 5                 8 Ave & W 52 St         NaN
# 6              E 11 St & Broadway         NaN
# 7        DeKalb Ave & Skillman St         NaN
# 8   Atlantic Ave & Fort Greene Pl         NaN
# 9               Avenue D & E 8 St         NaN
# 10           S 3 St & Bedford Ave         NaN
# 11         W Broadway & Spring St         NaN
# 12                2 Ave & E 31 St         NaN
# 13                E 33 St & 5 Ave         NaN
# 14       MacDougal St & Prince St         NaN
# 15   Clermont Ave & Lafayette Ave         NaN
# 16         Barclay St & Church St         NaN
# 17         Forsyth St & Broome St         NaN
# 18                W 13 St & 6 Ave         NaN
# ...

# %%
# Showing the number of trips started per station 
query = '''
SELECT start_station_name, COUNT(*) as trips
FROM fb55.citibike
GROUP BY start_station_name
ORDER BY trips DESC
'''

table = get_data(query)
table.head(20)
# Out:
#           start_station_name  trips
# 0            8 Ave & W 31 St    530
# 1            W 21 St & 6 Ave    519
# 2      Lafayette St & E 8 St    511
# 3            W 41 St & 8 Ave    507
# 4   E 43 St & Vanderbilt Ave    486
# 5         E 17 St & Broadway    455
# 6            W 31 St & 7 Ave    424
# 7            1 Ave & E 15 St    397
# 8            8 Ave & W 33 St    387
# 9         Broadway & E 14 St    373
# 10   Lexington Ave & E 24 St    372
# 11     Pershing Square South    362
# 12     Greenwich Ave & 8 Ave    342
# 13   University Pl & E 14 St    341
# 14           W 18 St & 6 Ave    327
# 15        Broadway & E 22 St    324
# 16     Pershing Square North    323
# 17           W 27 St & 7 Ave    320
# 18        Broadway & W 24 St    319
# 19           E 33 St & 2 Ave    319

# %%
# Showing the number of trips started for stations within 500m of Time Square!
# The coordinates of Time Square is (40.7577,-73.9857)
# One degree of latitude = 111.03 km 
# 500m = 0.004503 degrees 
# One degree of longtidue = 85.39 km
# 500m = 0.00585 degrees 
query = '''
SELECT start_station_name, COUNT(*) as trips
FROM
(SELECT *
FROM fb55.citibike
WHERE start_station_latitude < (40.7577 + 0.004503)
AND start_station_latitude > (40.7577 - 0.004503)
AND start_station_longitude < (-73.9857 + 0.00585)
AND start_station_longitude > (-73.9857 - 0.00585) ) AS subquery 
GROUP BY start_station_name
ORDER BY trips DESC
'''

table = get_data(query)
table.head(5)
# Out:
#    start_station_name  trips
# 0     W 41 St & 8 Ave    507
# 1     W 38 St & 8 Ave    289
# 2  Broadway & W 41 St    251
# 3     W 42 St & 8 Ave    221
# 4  Broadway & W 49 St    213

# %% [markdown]
# # Task 4 — Putting it all together

# %%
# Find the station that had the longest average trip duration during
# weekends and within 500m of TimeSquare! 
query = '''
SELECT start_station_name, AVG(tripduration) as avg_duration
FROM 
(SELECT start_station_name, tripduration, EXTRACT(DAY FROM starttime) as day 
FROM fb55.citibike
WHERE start_station_latitude < (40.7577 + 0.004503)
AND start_station_latitude > (40.7577 - 0.004503)
AND start_station_longitude < (-73.9857 + 0.00585)
AND start_station_longitude > (-73.9857 - 0.00585) ) AS subquery
WHERE day = 1 OR day = 2
GROUP BY start_station_name
ORDER BY avg_duration DESC
LIMIT 1
'''

table = get_data(query)
table.head(5)
# Out:
#   start_station_name  avg_duration
# 0    W 45 St & 8 Ave        1043.6

# %%
# Extra: create lines for trips started from stations within 500m of Times
# Squares and lasted less than 2 hours. The number of trips per each
# pair of stations are output as attributes of these lines. 
query = '''
SELECT start_station_name, end_station_name, COUNT(*) as trips
FROM fb55.citibike
WHERE start_station_latitude < (40.7577 + 0.004503)
AND start_station_latitude > (40.7577 - 0.004503)
AND start_station_longitude < (-73.9857 + 0.00585)
AND start_station_longitude > (-73.9857 - 0.00585)
AND tripduration < (60 * 60 * 2)
GROUP BY 1, 2
ORDER BY trips DESC
'''

table = get_data(query)
table.head(20)
# Out:
#     start_station_name          end_station_name  trips
# 0      W 41 St & 8 Ave  E 43 St & Vanderbilt Ave     31
# 1      W 41 St & 8 Ave        E 47 St & Park Ave     21
# 2      W 38 St & 8 Ave  E 43 St & Vanderbilt Ave     18
# 3      W 41 St & 8 Ave     Pershing Square South     17
# 4      W 51 St & 6 Ave           W 33 St & 7 Ave     17
# 5      W 42 St & 8 Ave          11 Ave & W 41 St     17
# 6      W 41 St & 8 Ave     Pershing Square North     15
# 7      W 38 St & 8 Ave           E 33 St & 2 Ave     15
# 8   Broadway & W 49 St  E 43 St & Vanderbilt Ave     15
# 9      W 43 St & 6 Ave  E 43 St & Vanderbilt Ave     14
# 10  Broadway & W 41 St           W 33 St & 7 Ave     14
# 11     W 41 St & 8 Ave           E 40 St & 5 Ave     14
# 12     W 45 St & 6 Ave           W 33 St & 7 Ave     14
# 13     W 41 St & 8 Ave          11 Ave & W 41 St     13
# 14     W 44 St & 5 Ave           W 33 St & 7 Ave     13
# 15  Broadway & W 49 St     E 48 St & Madison Ave     13
# ...

# %% [markdown]
# # extra credit: make the function python 2 and 3 compatible so that it works on the  PUI2016_Python3 kernel

# %% [markdown]
# did this by adding:
#
# try:
#     import urllib2 as urllib
# except ImportError:
#     import urllib.request as urllib
